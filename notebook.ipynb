# %%
from src.no_image import no_images

# 5,6,8,10
no_images(
        prompt="""
        Interior of a modern American house, featuring a cozy open-plan living room and kitchen. The space includes a comfortable sectional sofa, a large flat-screen TV mounted on the wall, a stylish kitchen island with bar stools, and warm lighting from hanging pendant lamps. Wooden floors, neutral-toned furniture, and large windows letting in natural sunlight create a welcoming and contemporary atmosphere. The image is photorealistic, with rich detail and balanced composition.
        
""",
        output_dir="/mnt/c/work/nano-banana-python-main/output",
        image_paths=None

    )
# Out:
# Remixing 0 image(s)
# Prompt:
#         Interior of a modern American house, featuring a cozy open-plan living room and kitchen. The space includes a comfortable sectional sofa, a large flat-screen TV mounted on the wall, a stylish kitchen island with bar stools, and warm lighting from hanging pendant lamps. Wooden floors, neutral-toned furniture, and large windows letting in natural sunlight create a welcoming and contemporary atmosphere. The image is photorealistic, with rich detail and balanced composition.
#
#
# Saved: /mnt/c/work/nano-banana-python-main/output/generated_1767113066_0.png

# %%
coffeeshop_prompt = """A realistic image of a hand holding a stylish 
phone case in the foreground, seamlessly integrated into the background
 of a cozy modern American coffeeshop. The hand and phone are well-lit 
 with soft natural light that matches the warm ambient lighting of the 
 café interior. The coffeeshop features wooden tables, comfortable 
 seating, hanging pendant lights, and sunlight streaming through 
 large windows. The atmosphere feels inviting and relaxed, with a 
 few blurred figures and coffee cups in the background to enhance 
 depth and authenticity. The overall look is natural and cohesive, 
 as if the phone case is being showcased in a real café environment. 
 Photorealistic style, high detail, and balanced composition."""

prompt="""A realistic image of a hand holding a stylish phone 
        case in the foreground, seamlessly blended into the background 
        of a cozy modern American living room. The hand and phone 
        are well-lit, with soft natural light matching the ambient 
        lighting of the room. The living room features a comfortable 
        sofa, warm neutral tones, wooden flooring, and sunlight 
        streaming through large windows. The overall look is natural 
        and cohesive, as if the phone case is being showcased in a 
        real home environment. Photorealistic style, high detail, 
        and balanced composition."""

industrial_prompt = """A realistic image of a hand holding a stylish phone case in the foreground, 
seamlessly integrated into the background of an industrial modern 
coffeeshop. The café features exposed brick walls, metal fixtures, 
and large factory-style windows letting in soft afternoon sunlight. 
The hand and phone are illuminated by gentle natural light, matching 
the café’s warm ambient tones. Wooden tables, black steel chairs, and
 hanging Edison bulbs create a stylish, urban mood. The composition is 
 balanced and detailed, with subtle depth-of-field blur for realism.""" 

scandinavian_prompt = """A photorealistic image of a hand holding a sleek 
phone case in a bright Scandinavian-style coffeeshop. The setting includes 
clean white walls, light wood furniture, potted green plants, and soft 
diffused natural light from large windows. The scene feels airy, calm, 
and cozy, with neutral color tones and subtle shadows. The focus remains 
on the hand and phone, blending naturally with the serene, minimalist 
background. Perfectly balanced lighting and detail for a premium lifestyle 
aesthetic."""     

russian_prompt = """A realistic image of a hand holding a stylish phone 
        case in the foreground, seamlessly integrated into the background 
        of a cozy modern Russian living room. The room features traditional 
        Russian decor elements
        such as ornate wooden furniture, patterned rugs, and warm textiles. 
        The hand and phone are well-lit with soft natural light that 
        complements the warm ambient lighting of the room. Large windows 
        allow sunlight to stream in,
        enhancing the inviting atmosphere. The overall look is natural 
        and cohesive, as if the phone case is being showcased in a real 
        home environment. Photorealistic style, high detail, and balanced 
        composition."""            

women_holding = """
A realistic image of a young woman holding a stylish phone case 
naturally in her hand, positioned in the foreground. The woman 
is using a yellow dress, with a relaxed, authentic 
posture. The background shows a warm modern coffeeshop interior with 
wooden tables, pendant lights, and sunlight streaming through large windows. The lighting on the woman and phone matches the café’s ambient tones, creating a cohesive and photorealistic lifestyle scene. High detail and natural composition, suitable for marketing or product showcase.
"""                     

women_holding_2 = """A realistic, photorealistic image of a young woman 
shown from the shoulders to mid-torso, holding the same phone and 
phone case as in the reference image, with identical position, size,
 and angle. The phone design, case shape, and reflective details remain
   unchanged. The woman’s pose and hand placement are identical to the 
   reference composition. Her face is not visible — only her upper body 
   and hands are shown. In this version, she is wearing a yellow dress 
   with natural folds and texture. The background is a warm modern 
   coffeeshop interior with wooden tables, pendant lights, and 
   sunlight streaming through large windows. The lighting on her hands, 
   clothing, and phone matches the café’s ambient tones, creating 
   a cohesive and realistic lifestyle scene. High detail, natural color 
   balance, and consistent framing suitable for product marketing."""

# %%
from src.with_image import remix_images


promt = """ Use the provided reference image exactly as-is. 
Place the phone from the reference image naturally on a wooden 
café table inside a modern Starbucks-style coffee shop. 
The background shows a cozy interior with warm ambient lighting, 
soft shadows, wooden textures, and blurred details of a café 
environment. Do not alter the phone, its lighting, or reflections.
Do not show any Starbucks logos, cups, or branded items. The scene 
should look realistic and well-lit, focusing on the phone placed on
 the table."""

# 5,6,8,10
remix_images(
        prompt=promt,
        output_dir="/mnt/c/work/nano-banana-python-main/output14",
        MODEL_NAME=MODEL_NAME, 
        image_paths=[ "/mnt/c/work/nano-banana-python-main/images/6.jpeg"]

    )
# Out:
# Remixing 1 image(s)
# Prompt:  Use the provided reference image exactly as-is.
# Place the phone from the reference image naturally on a wooden
# café table inside a modern Starbucks-style coffee shop.
# The background shows a cozy interior with warm ambient lighting,
# soft shadows, wooden textures, and blurred details of a café
# environment. Do not alter the phone, its lighting, or reflections.
# Do not show any Starbucks logos, cups, or branded items. The scene
# should look realistic and well-lit, focusing on the phone placed on
#  the table.
# Saved: /mnt/c/work/nano-banana-python-main/output14/remixed_1767270732_0.jpg

# %%
promt = """A realistic image of a hand holding the same smartphone with 
its custom phone case inside a Starbucks-style coffee shop. The background 
remains the same warm, wooden café interior with soft ambient lighting. 
The hand appears natural, with no sleeves or jewelry, and holds the phone 
in a relaxed, realistic grip. No Starbucks logos or cups are visible."""

promt1 = """
change the table to be a starbucs style table, 
No Starbucks logos or cups are visible. Remove the magazine.
"""
promt2 = """
make the caucasian women to be mirror selfieing, dont change the phone position.
"""

promt3 = """
make the background to be inside a coffee shop. dont change the phone position.
"""

# %%
from src.with_image import remix_images

MODEL_NAME = "gemini-2.5-flash-image-preview"
MODEL_NAME_PRO = "gemini-3-pro-image-preview"


# 5,6,8,10
remix_images(
        prompt=promt1,
        output_dir="/mnt/c/work/nano-banana-python-main/output dimeja",
        MODEL_NAME=MODEL_NAME_PRO,
        image_paths=[ "/mnt/c/work/nano-banana-python-main/dimeja/5.jpeg"]

    )
# Out:
# Remixing 1 image(s)
# Prompt:
# change the table to be a starbucs style table,
# No Starbucks logos or cups are visible. Remove the magazine.
#
# Saved: /mnt/c/work/nano-banana-python-main/output dimeja/remixed_1767349038_0.jpg

# %%
# foto dimeja
# foto tangan ganti background
# foto ada badan

# %%
promt = """A realistic, cinematic product photo set inside a Star Wars–style spaceship interior during daytime. On a smooth metallic table with subtle sci-fi panel lines, several cute silicone AirPods cases stand upright in a neat arrangement. Each case is designed as an iconic Star Wars character, with soft matte textures and charming proportions. The background features a softly blurred starship interior with futuristic walls, glowing control panels, and a large viewport window revealing a distant planet and starfield. Natural daylight streams through the window, mixing with gentle ambient sci-fi lighting, creating soft reflections on the table surface. Shallow depth of field, professional lifestyle product photography, ultra-realistic details, cinematic composition, warm yet futuristic atmosphere."""

# %%
from pathlib import Path
from src.with_image import remix_images
import time

MODEL_NAME = "gemini-2.5-flash-image"
MODEL_NAME_PRO = "gemini-3-pro-image-preview"
MODEL_FLASH_PRO = "gemini-3.1-flash-image-preview"

image_dir = Path("/mnt/c/work/nano-banana-python-main/images")
output_dir = "/mnt/c/work/nano-banana-python-main/output14"

for image_path in image_dir.iterdir():
    if image_path.suffix.lower() not in [".jpg", ".jpeg", ".png", ".webp"]:
        continue

    remix_images(
        prompt=promt,
        output_dir=output_dir,
        MODEL_NAME=MODEL_FLASH_PRO,
        image_paths=[str(image_path)],
        api_key="AIzaSyBRPVDNaqk-kis4UT8I4orH_lnJEsrWISM"  # SINGLE image per call
    )

# %%
from google import genai

client = genai.Client(api_key="AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48")

for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/embedding-001
# ...

# %%
from google import genai
from PIL import Image

# Initialize client
client = genai.Client(api_key="AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48")

# Load image
image = Image.open("/mnt/c/work/nano-banana-python-main/images/Untitled design.png")

# Generate content
response = client.models.generate_content(
    model="gemini-3-pro-preview",
    contents=["Describe this image in detail", image]
)

print(response.text)

# %%
import PIL.Image
import io
from google import genai
from google.genai import types

# Use your API key or set up Application Default Credentials
client = genai.Client(api_key="AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48")

# 1. Prepare your reference image
image_path = '/mnt/c/work/nano-banana-python-main/images/Untitled design.png'
image = PIL.Image.open(image_path)

# 2. Convert PIL Image to bytes
img_byte_arr = io.BytesIO()
image.save(img_byte_arr, format='PNG')
img_bytes = img_byte_arr.getvalue()

# 3. Request Image Generation
# Specify "IMAGE" as the modality to output a file
response = client.models.generate_content(
    # model='gemini-3-pro-image-preview',
    model='gemini-2.5-flash-image',
    contents=[
        "Remix this image to be in a 3D claymation style",
        types.Part.from_bytes(data=img_bytes, mime_type='image/png')
    ],
    config=types.GenerateContentConfig(
        response_modalities=["IMAGE"],
        image_config=types.ImageConfig(
            aspect_ratio="1:1"  # Optional: "1:1", "16:9", "4:3", etc.
        )
    )
)

# 4. Save and view the generated image
for part in response.parts:
    if image_data := part.as_image():
        image_data.save("generated_remix.png")
        image_data.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 36
#      20 response = client.models.generate_content(
#      21     # model='gemini-3-pro-image-preview',
#      22     model='gemini-2.5-flash-image',
#    (...)
#      32     )
#      33 )
#      35 # 4. Save and view the generated image
# ---> 36 for part in response.parts:
#      37     if image_data := part.as_image():
#      38         image_data.save("generated_remix.png")
#
# TypeError: 'NoneType' object is not iterable

# %%
import PIL.Image
import io
from google import genai
from google.genai import types

# =========================
# CONFIG
# =========================
API_KEY = "AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48"
IMAGE_PATH = "/mnt/c/work/nano-banana-python-main/images/Untitled design.png"
OUTPUT_FILE = "generated_remix.png"

# =========================
# Setup client
# =========================
client = genai.Client(api_key=API_KEY)

# =========================
# Load image
# =========================
image = PIL.Image.open(IMAGE_PATH)

img_byte_arr = io.BytesIO()
image.save(img_byte_arr, format="PNG")
img_bytes = img_byte_arr.getvalue()

# =========================
# Generate image remix
# =========================
response = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents=[
        "A realistic, cinematic product photo set inside a Star Wars–style spaceship interior during daytime. On a smooth metallic table with subtle sci-fi panel lines, several cute silicone AirPods cases stand upright in a neat arrangement. Each case is designed as an iconic Star Wars character, with soft matte textures and charming proportions. The background features a softly blurred starship interior with futuristic walls, glowing control panels, and a large viewport window revealing a distant planet and starfield. Natural daylight streams through the window, mixing with gentle ambient sci-fi lighting, creating soft reflections on the table surface. Shallow depth of field, professional lifestyle product photography, ultra-realistic details, cinematic composition, warm yet futuristic atmosphere.",
        types.Part.from_bytes(data=img_bytes, mime_type="image/png"),
    ],
    config=types.GenerateContentConfig(
        response_modalities=["IMAGE"],
        image_config=types.ImageConfig(
            aspect_ratio="1:1"
        ),
    ),
)

# =========================
# Extract & save images
# =========================
saved_any = False

if not response or not response.candidates:
    raise RuntimeError("No candidates returned from model")

for i, candidate in enumerate(response.candidates):
    if not candidate.content or not candidate.content.parts:
        continue

    for j, part in enumerate(candidate.content.parts):
        image_data = part.as_image()
        if image_data:
            filename = OUTPUT_FILE if saved_any is False else f"generated_remix_{i}_{j}.png"
            image_data.save(filename)
            image_data.show()
            print(f"Saved image: {filename}")
            saved_any = True

if not saved_any:
    print("No image parts found in response.")
    print("Full response for debugging:")
    print(response.model_dump_json(indent=2))
# Out:
# No image parts found in response.
# Full response for debugging:
# {
#   "sdk_http_response": {
#     "headers": {
#       "content-type": "application/json; charset=UTF-8",
#       "vary": "Origin, X-Origin, Referer",
#       "content-encoding": "gzip",
#       "date": "Sat, 31 Jan 2026 01:33:59 GMT",
#       "server": "scaffolding on HTTPServer2",
#       "x-xss-protection": "0",
#       "x-frame-options": "SAMEORIGIN",
#       "x-content-type-options": "nosniff",
#       "server-timing": "gfet4t7; dur=1272",
#       "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000",
#       "transfer-encoding": "chunked"
#     },
#     "body": null
#   },
#   "candidates": [
#     {
#       "content": null,
#       "citation_metadata": null,
#       "finish_message": null,
#       "token_count": null,
#       "finish_reason": "NO_IMAGE",
#       "avg_logprobs": null,
#       "grounding_metadata": null,
#       "index": 0,
#       "logprobs_result": null,
# ...

# %%
import PIL.Image
import io
import time
from google import genai
from google.genai import types

API_KEY = "AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48"
IMAGE_PATH = "/mnt/c/work/nano-banana-python-main/images/Untitled design.png"

client = genai.Client(api_key=API_KEY)

# Load image
image = PIL.Image.open(IMAGE_PATH)
img_byte_arr = io.BytesIO()
image.save(img_byte_arr, format="PNG")
img_bytes = img_byte_arr.getvalue()

prompt = """
Create a brand new image remix of this picture.
Render it in 3D claymation style.
The output MUST be an image.
No text. Image only.
"""

def generate_with_retry(max_attempts=5):
    for attempt in range(max_attempts):
        print(f"Attempt {attempt+1}...")

        response = client.models.generate_content(
            model="gemini-2.5-flash-image",
            contents=[
                prompt,
                types.Part.from_bytes(data=img_bytes, mime_type="image/png"),
            ],
            config=types.GenerateContentConfig(
                response_modalities=["IMAGE"]
            ),
        )

        for candidate in response.candidates or []:
            if candidate.content and candidate.content.parts:
                for part in candidate.content.parts:
                    image_data = part.as_image()
                    if image_data:
                        return image_data

        print("No image returned. Retrying...")
        time.sleep(2)

    raise RuntimeError("Failed after retries")

# Generate
result_image = generate_with_retry()

# Save & show
result_image.save("generated_remix.png")
result_image.show()

print("Saved: generated_remix.png")
# Out:
# Attempt 1...
# No image returned. Retrying...
# Attempt 2...
# No image returned. Retrying...
# Attempt 3...
# No image returned. Retrying...
# Attempt 4...
# No image returned. Retrying...
# Attempt 5...
# No image returned. Retrying...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 53
#      50     raise RuntimeError("Failed after retries")
#      52 # Generate
# ---> 53 result_image = generate_with_retry()
#      55 # Save & show
#      56 result_image.save("generated_remix.png")
#
# Cell In[18], line 50, in generate_with_retry(max_attempts)
#      47     print("No image returned. Retrying...")
#      48     time.sleep(2)
# ---> 50 raise RuntimeError("Failed after retries")
#
# RuntimeError: Failed after retries

# %%
import PIL.Image
from google import genai
from google.genai import types

client = genai.Client(api_key="AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48")

# Load your source image
source_img = PIL.Image.open("/mnt/c/work/nano-banana-python-main/images/Untitled design.png")

response = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents=[
        "A realistic, cinematic product photo set inside a Star Wars–style spaceship interior during daytime. On a smooth metallic table with subtle sci-fi panel lines, several cute silicone AirPods cases stand upright in a neat arrangement. Each case is designed as an iconic Star Wars character, with soft matte textures and charming proportions. The background features a softly blurred starship interior with futuristic walls, glowing control panels, and a large viewport window revealing a distant planet and starfield. Natural daylight streams through the window, mixing with gentle ambient sci-fi lighting, creating soft reflections on the table surface. Shallow depth of field, professional lifestyle product photography, ultra-realistic details, cinematic composition, warm yet futuristic atmosphere.", 
        source_img
    ],
    config=types.GenerateContentConfig(
        response_modalities=["IMAGE"],
        safety_settings=[
        {"category": "HARM_CATEGORY_HARASSMENT", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_HATE_SPEECH", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_SEXUALLY_EXPLICIT", "threshold": "BLOCK_NONE"},
        {"category": "HARM_CATEGORY_DANGEROUS_CONTENT", "threshold": "BLOCK_NONE"},
    ]

    )
)

# Save the edited output
for part in response.candidates[0].content.parts:
    if part.inline_data:
        with open("edited_image.png", "wb") as f:
            f.write(part.inline_data.data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 29
#      10 response = client.models.generate_content(
#      11     model="gemini-2.5-flash-image",
#      12     contents=[
#    (...)
#      25     )
#      26 )
#      28 # Save the edited output
# ---> 29 for part in response.candidates[0].content.parts:
#      30     if part.inline_data:
#      31         with open("edited_image.png", "wb") as f:
#
# AttributeError: 'NoneType' object has no attribute 'parts'

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(),
#       finish_reason=<FinishReason.OTHER: 'OTHER'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-3-pro-image-preview',
#   response_id='TV19acezItu6qfkP6r-s8Ag',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     prompt_token_count=398,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=140
#       ),
#       ModalityTokenCount(
#         modality=<MediaModality.IMAGE: 'IMAGE'>,
#         token_count=258
#       ),
#     ],
#     thoughts_token_count=176,
#     total_token_count=574
#   )
# )

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key="AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48") 

chat = client.chats.create(
    model="gemini-3-pro-image-preview",
    config=types.GenerateContentConfig(
        response_modalities=['TEXT', 'IMAGE'],
        tools=[{"google_search": {}}]
    )
)

message = "Create a vibrant infographic that explains photosynthesis as if it were a recipe for a plant's favorite food. Show the \"ingredients\" (sunlight, water, CO2) and the \"finished dish\" (sugar/energy). The style should be like a page from a colorful kids' cookbook, suitable for a 4th grader."

response = chat.send_message(message)

for part in response.parts:
    if part.text is not None:
        print(part.text)
    elif image:= part.as_image():
        image.save("photosynthesis.png")

# %%
from google import genai
from google.genai import types
from PIL import Image

client = genai.Client(api_key="AIzaSyClRMEKUbHj6O3l7YqobNczVq0E5ME_y48") 

prompt = """
A realistic cinematic product photo set inside a futuristic sci-fi spaceship interior.
On a smooth metallic table with subtle panel lines, several cute silicone AirPods cases
stand upright in a neat arrangement. Each case is designed as a charming space hero
character with soft matte textures and playful proportions.

The background features a softly blurred starship interior with glowing control panels
and a large viewport window revealing a distant planet and starfield. Natural daylight
streams through the window, mixing with gentle ambient sci-fi lighting.

Shallow depth of field, professional lifestyle product photography,
ultra-realistic details, cinematic composition, warm futuristic atmosphere.
"""


image = Image.open("/mnt/c/work/nano-banana-python-main/images/Untitled design.png")

response = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents=[prompt, image],
)

if not response or not response.candidates:
    print("No candidates returned.")
    print(response)
else:
    candidate = response.candidates[0]

    if not candidate.content or not candidate.content.parts:
        print("No parts in candidate.")
    else:
        for part in candidate.content.parts:
            if part.text:
                print(part.text)
            elif part.inline_data:
                img = part.as_image()
                img.save("generated_image.png")
# Out:
# No parts in candidate.
